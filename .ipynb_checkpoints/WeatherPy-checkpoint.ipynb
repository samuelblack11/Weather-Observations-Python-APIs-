# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
from citipy import citipy
import random
import requests
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"

# %%
## Create list of 500 unique cities 
cities=[]


url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

lats = []
temp_f=[]
humidity=[]
cloudiness=[]
wind_speed=[]

dup_count=0
counter = 0
#for counter in range(0,500):
while counter < 500:    
    rand_lat = random.uniform(-90, 90)
    rand_lng = random.uniform(-180, 180)
    #coordinates=(rand_lat,rand_lng)
    city = citipy.nearest_city(rand_lat, rand_lng)
    name = city.city_name
    country= city.country_code
    full_city_name=(f'{name}, {country}')
    # Ensure it is unique cities only
    if name not in cities:
        response = requests.get(query_url +name).json()
        try:
            lat=(response['coord']['lat'])
            cities.append(name)
            lats.append(lat)
            temp_f.append(response['main']['temp'])
            cloudiness.append(response['clouds']['all'])
            humidity.append(response['main']['humidity'])
            wind_speed.append(response['wind']['speed'])
            counter +=1
            print(f'{counter}.{name}')
        except KeyError as e:
            dup_count+=1
            print('City not found. Skipping...')
        lat = None
    #else:
        #print(None)
# Out:
# 1.qaanaaq
# 2.sept-iles
# 3.pevek
# City not found. Skipping...
# 4.east london
# City not found. Skipping...
# 5.provideniya
# 6.lagoa
# 7.muros
# City not found. Skipping...
# 8.cape town
# City not found. Skipping...
# 9.tuatapere
# 10.yulara
# City not found. Skipping...
# 11.airai
# 12.busselton
# 13.epernay
# City not found. Skipping...
# 14.margate
# 15.esperance
# 16.cabedelo
# City not found. Skipping...
# 17.coahuayana
# 18.puerto ayora
# City not found. Skipping...
# City not found. Skipping...
# 19.albany
# 20.bluff
# 21.phan thiet
# 22.baracoa
# 23.atuona
# 24.rikitea
# 25.oussouye
# 26.avarua
# 27.lata
# 28.nanortalik
# 29.mataura
# 30.kodiak
# 31.telimele
# 32.lebu
# 33.damme
# 34.ushuaia
# 35.nantucket
# 36.hobart
# 37.bredasdorp
# 38.new norfolk
# 39.hasaki
# 40.biankouma
# City not found. Skipping...
# 41.severo-kurilsk
# 42.pisco
# City not found. Skipping...
# 43.sao miguel do araguaia
# 44.kuala terengganu
# 45.bayonet point
# 46.hamilton
# City not found. Skipping...
# 47.jamestown
# 48.tucupita
# 49.punta arenas
# 50.sambava
# 51.bull savanna
# 52.yellowknife
# 53.hambantota
# 54.henties bay
# City not found. Skipping...
# 55.grand gaube
# 56.sisimiut
# 57.tasiilaq
# City not found. Skipping...
# 58.ugoofaaru
# 59.tiksi
# 60.upernavik
# 61.hermanus
# 62.meulaboh
# 63.viedma
# 64.chabahar
# 65.san luis
# 66.show low
# 67.kaka
# 68.rio grande
# 69.hilo
# 70.shahr-e babak
# 71.puerto del rosario
# 72.caravelas
# 73.saint george
# 74.bethel
# 75.castro
# City not found. Skipping...
# 76.kloulklubed
# 77.hithadhoo
# 78.yantikovo
# 79.lunenburg
# City not found. Skipping...
# 80.ancud
# City not found. Skipping...
# 81.pesaro
# 82.calvinia
# 83.sao filipe
# 84.carnarvon
# City not found. Skipping...
# 85.zeya
# 86.ginir
# 87.pudozh
# 88.buraydah
# 89.camacha
# City not found. Skipping...
# 90.karasburg
# 91.vardo
# 92.bulgan
# 93.loandjili
# 94.khatanga
# 95.faya
# 96.cayenne
# 97.keningau
# 98.alice springs
# 99.flinders
# 100.vila franca do campo
# 101.port lincoln
# 102.nikolskoye
# 103.dolores
# 104.dombarovskiy
# 105.naze
# 106.saint-philippe
# 107.iqaluit
# City not found. Skipping...
# 108.touros
# 109.garden city
# 110.ixtapa
# 111.makubetsu
# 112.ribeira grande
# 113.inhambane
# 114.san cristobal
# 115.kapaa
# 116.mogadishu
# 117.yangambi
# 118.deputatskiy
# 119.ponta do sol
# 120.namatanai
# 121.guerrero negro
# 122.port elizabeth
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 123.la rioja
# 124.porto walter
# 125.kavaratti
# 126.avera
# 127.port alfred
# 128.torbay
# 129.sarana
# 130.wilmington
# 131.melita
# City not found. Skipping...
# 132.ankang
# 133.cabo san lucas
# 134.thompson
# 135.kahului
# 136.erzin
# 137.ust-maya
# 138.sakaiminato
# City not found. Skipping...
# 139.tiarei
# 140.dubasari
# 141.butaritari
# City not found. Skipping...
# 142.balclutha
# 143.coquimbo
# City not found. Skipping...
# 144.laguna
# 145.gornopravdinsk
# 146.lufilufi
# 147.georgetown
# 148.marsa matruh
# 149.kirakira
# 150.longyearbyen
# 151.vikhorevka
# 152.bella union
# 153.lubbock
# 154.hualmay
# 155.college
# 156.vaini
# 157.dikson
# 158.yarensk
# 159.ketchikan
# 160.douentza
# 161.cidreira
# 162.nyeri
# 163.port augusta
# 164.bara
# 165.markova
# 166.sola
# 167.ajdabiya
# 168.progreso
# 169.mount isa
# 170.norman wells
# 171.ust-nera
# 172.westport
# 173.tres picos
# 174.eydhafushi
# 175.hami
# 176.chiang klang
# 177.raudeberg
# 178.sartell
# 179.chokurdakh
# 180.xique-xique
# 181.barrow
# 182.saldanha
# 183.sao joao da barra
# 184.fukue
# 185.ahuimanu
# 186.dogondoutchi
# 187.maryborough
# City not found. Skipping...
# 188.vestmanna
# 189.ciudad valles
# 190.mongo
# City not found. Skipping...
# 191.pestravka
# 192.ivanteyevka
# City not found. Skipping...
# 193.saskylakh
# 194.bonthe
# 195.masterton
# 196.sioux lookout
# 197.tommot
# 198.tuktoyaktuk
# 199.mar del plata
# 200.sitka
# 201.cururupu
# 202.amahai
# 203.biak
# 204.carora
# 205.narsaq
# 206.te anau
# City not found. Skipping...
# City not found. Skipping...
# 207.kruisfontein
# 208.cachoeira do sul
# 209.todos santos
# 210.izumo
# 211.jinchang
# 212.kungurtug
# 213.daoukro
# City not found. Skipping...
# 214.souillac
# 215.faanui
# City not found. Skipping...
# 216.lethem
# 217.atasu
# City not found. Skipping...
# 218.okha
# 219.fortuna
# City not found. Skipping...
# City not found. Skipping...
# 220.hovd
# 221.aykhal
# 222.corovode
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 223.klaksvik
# 224.gravdal
# City not found. Skipping...
# 225.constitucion
# 226.paramonga
# City not found. Skipping...
# 227.banes
# 228.sangar
# 229.waipawa
# 230.aswan
# 231.san juan
# 232.buin
# 233.lienz
# 234.miranda
# 235.talnakh
# 236.mnogovershinnyy
# 237.ostrovnoy
# 238.grojec
# 239.koslan
# 240.kaitangata
# 241.saint-joseph
# 242.isangel
# 243.mansoa
# 244.chateaubelair
# 245.port pirie
# 246.keetmanshoop
# 247.manzhouli
# 248.bambous virieux
# 249.volkach
# 250.royan
# 251.umm bab
# 252.puerto guzman
# 253.mecca
# 254.arraial do cabo
# 255.lompoc
# 256.naliya
# 257.the valley
# City not found. Skipping...
# 258.muroto
# City not found. Skipping...
# 259.sri aman
# City not found. Skipping...
# 260.egvekinot
# City not found. Skipping...
# 261.katsuura
# City not found. Skipping...
# City not found. Skipping...
# 262.luderitz
# City not found. Skipping...
# 263.kavieng
# 264.sabzevar
# City not found. Skipping...
# 265.aklavik
# 266.baykit
# 267.coihaique
# 268.shingu
# 269.los llanos de aridane
# 270.east moline
# 271.quatre cocos
# 272.tondano
# 273.paita
# 274.seoul
# 275.burntwood
# 276.vostok
# 277.manavalakurichi
# 278.anqiu
# 279.alofi
# 280.sobolevo
# 281.hofn
# 282.port hedland
# 283.altay
# City not found. Skipping...
# 284.daru
# 285.beringovskiy
# City not found. Skipping...
# 286.muramatsu
# 287.umm kaddadah
# 288.thiruvananthapuram
# 289.fallon
# City not found. Skipping...
# 290.nabire
# City not found. Skipping...
# 291.xining
# 292.labuhan
# 293.jawar
# City not found. Skipping...
# 294.gladstone
# City not found. Skipping...
# 295.husavik
# City not found. Skipping...
# 296.la ronge
# 297.yar-sale
# 298.cherskiy
# 299.newport
# 300.marawi
# 301.vallenar
# 302.teya
# 303.ciudad bolivar
# City not found. Skipping...
# 304.chara
# City not found. Skipping...
# 305.niquelandia
# 306.kieta
# 307.tomatlan
# 308.san patricio
# 309.nizhneudinsk
# City not found. Skipping...
# 310.kudahuvadhoo
# 311.wuchang
# City not found. Skipping...
# 312.morondava
# 313.quesnel
# 314.mount gambier
# 315.kamiiso
# City not found. Skipping...
# 316.lerwick
# 317.hauterive
# 318.lumphat
# 319.hermiston
# 320.balkanabat
# 321.geraldton
# 322.imbituva
# 323.muisne
# 324.mandili
# 325.mahebourg
# City not found. Skipping...
# 326.simplicio mendes
# 327.yengema
# City not found. Skipping...
# 328.fairbanks
# 329.strzelce krajenskie
# 330.chingola
# 331.bandarbeyla
# City not found. Skipping...
# 332.pangnirtung
# 333.sumenep
# 334.kalmunai
# 335.palauig
# City not found. Skipping...
# 336.vanavara
# City not found. Skipping...
# City not found. Skipping...
# 337.jawhar
# 338.vangaindrano
# 339.mahon
# 340.maragogi
# 341.zinder
# 342.sinnamary
# City not found. Skipping...
# 343.high level
# 344.nelson bay
# 345.kattivakkam
# City not found. Skipping...
# 346.lavrentiya
# 347.muyezerskiy
# 348.ilulissat
# 349.spring hill
# City not found. Skipping...
# City not found. Skipping...
# 350.salalah
# 351.berlevag
# 352.jalu
# 353.birin
# City not found. Skipping...
# 354.port blair
# 355.nome
# 356.chuy
# 357.flin flon
# 358.dalbandin
# 359.kautokeino
# 360.bowen
# 361.lorengau
# 362.port hardy
# City not found. Skipping...
# 363.mookane
# 364.mpika
# 365.zhigansk
# 366.makat
# 367.fort walton beach
# 368.pangai
# 369.victoria
# City not found. Skipping...
# City not found. Skipping...
# 370.mahajanga
# City not found. Skipping...
# 371.araouane
# 372.ambilobe
# 373.mocuba
# 374.aljezur
# 375.iskateley
# 376.yerbogachen
# 377.itaqui
# City not found. Skipping...
# City not found. Skipping...
# 378.ko samui
# 379.gidam
# 380.chiredzi
# City not found. Skipping...
# City not found. Skipping...
# 381.elko
# 382.praya
# 383.zabaykalsk
# 384.vao
# 385.makakilo city
# 386.pocone
# 387.fallingbostel
# 388.masumbwe
# 389.kholm
# 390.swellendam
# City not found. Skipping...
# 391.tiznit
# 392.ternate
# City not found. Skipping...
# 393.statesboro
# 394.gotsu
# 395.kandrian
# 396.guayaramerin
# 397.wellington
# 398.linhai
# City not found. Skipping...
# 399.merauke
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 400.biltine
# City not found. Skipping...
# City not found. Skipping...
# 401.coroico
# 402.buchanan
# 403.kaiyuan
# 404.taltal
# 405.ahvaz
# 406.dunedin
# 407.walvis bay
# 408.preston
# City not found. Skipping...
# City not found. Skipping...
# 409.lewistown
# City not found. Skipping...
# 410.atikokan
# 411.iquitos
# 412.kaspiysk
# 413.bagotville
# 414.yarkovo
# 415.rocha
# 416.clyde river
# 417.kushima
# 418.khani
# City not found. Skipping...
# 419.aksarka
# City not found. Skipping...
# 420.ambon
# 421.chaoyang
# 422.dawson creek
# 423.komsomolskiy
# City not found. Skipping...
# 424.codrington
# 425.hearst
# City not found. Skipping...
# 426.pokrovsk
# 427.karratha
# 428.tura
# 429.napasar
# City not found. Skipping...
# 430.coron
# City not found. Skipping...
# 431.begun
# 432.zhanakorgan
# City not found. Skipping...
# City not found. Skipping...
# 433.curaca
# 434.anadyr
# City not found. Skipping...
# 435.comodoro rivadavia
# 436.vilyuysk
# 437.kigoma
# 438.ust-omchug
# 439.erdenet
# 440.ambanja
# 441.riyadh
# City not found. Skipping...
# 442.sao miguel
# 443.palmer
# 444.poum
# 445.zhuhai
# 446.boguchany
# 447.murray bridge
# 448.freeport
# 449.celestun
# 450.keti bandar
# 451.abu samrah
# 452.nemuro
# City not found. Skipping...
# 453.boyuibe
# 454.shache
# 455.ust-karsk
# 456.nanning
# 457.ende
# 458.waterloo
# 459.port keats
# City not found. Skipping...
# 460.weligama
# 461.ostersund
# 462.trelew
# 463.anshun
# 464.longyan
# 465.okhotsk
# 466.srednekolymsk
# 467.alindao
# 468.bichena
# 469.port-cartier
# 470.mill valley
# 471.kirensk
# 472.abu dhabi
# City not found. Skipping...
# 473.jingdezhen
# 474.nampula
# City not found. Skipping...
# 475.parsons
# 476.bonavista
# 477.kijang
# 478.katy
# City not found. Skipping...
# 479.pangody
# City not found. Skipping...
# City not found. Skipping...
# 480.bantogon
# 481.petropavlovsk-kamchatskiy
# City not found. Skipping...
# City not found. Skipping...
# 482.rocky mountain house
# 483.vanimo
# City not found. Skipping...
# City not found. Skipping...
# 484.fereydunshahr
# City not found. Skipping...
# 485.gizo
# 486.suntar
# City not found. Skipping...
# 487.barao de melgaco
# City not found. Skipping...
# 488.el tocuyo
# City not found. Skipping...
# 489.solnechnyy
# 490.lahij
# 491.port macquarie
# 492.benguela
# City not found. Skipping...
# 493.shimoda
# 494.teknaf
# City not found. Skipping...
# 495.broome
# 496.ondjiva
# City not found. Skipping...
# 497.novo cruzeiro
# City not found. Skipping...
# 498.nurota
# 499.linxia
# City not found. Skipping...
# 500.nishihara

# %%
# Verify there are 500 lats and cities in the lists
len(cities)
#len(lats)
dup_count
# Out:
# 123

# %%
df = pd.DataFrame({
        'City Name': cities,
        'Latitude': lats,  
        'Temp': temp_f,
        'Humidity': humidity,
        'Cloudiness': cloudiness,
        'Wind Speed': wind_speed,
    })

df=df.sort_values(['Latitude'], ascending=[True])
ordered_cities=df['City Name'].tolist()
ordered_lats=df['Latitude'].tolist()
df.head()
df.to_csv('weather_data.csv')

# %%
## Verify values

url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url +'collie').json()

#(response['coord']['lat'])
#(response['main']['temp'])
#(response['clouds']['all'])
#(response['main']['humidity'])
#(response['wind']['speed'])

# %%
# Started with seperate loops for cities, weeded out duplicates
# First had a for loop with counter. Debugged by using while loop for counter <30
# This is rather than using a for loop for counter in range (0,30), which was 30 iterations of counter not the value of the counter

# In a SEPERATE loop, used try/except to see if the city had data associated with it for lat
# Had to append None value to list to keep cities and lats the same length

# A more elegant solution was to only append a city to the cities list if it had data associated with it for lat IN THE SAME LOOP
# this eliminated the need to double check. The If statement filtered for duplicates, and the try statement filtered for cities without data.
# If it errored out on the line that set the value for lat, the city was not added to the list.

# And just moved to the next randomized city. Without this step, cities/lats were paired incorrectly, 
# or the lists of cities/lats were different lenghts, which caused an error when we tried to make a dataframe
# I then ordered the lats, then appended the other metrics in a SEPERATE loop
# Once it was working, just added all the metrics to the same try/except statement as for I did for lat and eliminated the seperate loop

# In summary: start off by breaking it into pieces, then put it together to make it more efficient
# I first had 3 seperate loops to break down the problem and find out what wasn't working.
# This is great for debugging, but not efficient for a final product

# %%
plt.grid()
plt.title("Temp(F) vs. Latitude (10/5)")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.ylim((-10), (120))

plt.scatter(lats, temp_f, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Temp(F) vs. Latitude.png")

# %%
plt.grid()
plt.title("Cloudiness vs. Latitude (10/5)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.ylim((-5), (105))

plt.scatter(lats, cloudiness, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Cloudiness vs. Latitude.png")

# %%
plt.grid()
plt.title("Humidity vs. Latitude (10/5)")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.ylim((0), (105))

plt.scatter(lats, humidity, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Humidity vs. Latitude.png")

# %%
plt.grid()
plt.title("Wind Speed vs. Latitude (10/5)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.ylim((0), (45))

plt.scatter(lats, wind_speed, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Wind Speed vs. Latitude.png")
