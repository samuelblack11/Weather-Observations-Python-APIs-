# %%
# Import Dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import json
from citipy import citipy
import random
import requests
api_key = "25bc90a1196e6f153eece0bc0b0fc9eb"

# %%
## Create list of 500 unique cities 
cities=[]


url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

lats = []
temp_f=[]
humidity=[]
cloudiness=[]
wind_speed=[]

dup_count=0
counter = 0
#for counter in range(0,500):
while counter < 500:    
    rand_lat = random.uniform(-90, 90)
    rand_lng = random.uniform(-180, 180)
    #coordinates=(rand_lat,rand_lng)
    city = citipy.nearest_city(rand_lat, rand_lng)
    name = city.city_name
    country= city.country_code
    full_city_name=(f'{name}, {country}')
    # Ensure it is unique cities only
    if name not in cities:
        response = requests.get(query_url +name).json()
        try:
            lat=(response['coord']['lat'])
            cities.append(name)
            lats.append(lat)
            temp_f.append(response['main']['temp'])
            cloudiness.append(response['clouds']['all'])
            humidity.append(response['main']['humidity'])
            wind_speed.append(response['wind']['speed'])
            counter +=1
            print(f'{counter}.{name}')
        except KeyError as e:
            dup_count+=1
            print('City not found. Skipping...')
        lat = None
    #else:
        #print(None)
# Out:
# 1.eureka
# City not found. Skipping...
# 2.butaritari
# 3.bluff
# 4.albany
# 5.new norfolk
# 6.el alto
# 7.atuona
# 8.beringovskiy
# 9.esna
# 10.dikson
# 11.touros
# 12.cabo san lucas
# 13.port alfred
# 14.bethel
# 15.beisfjord
# 16.sitka
# 17.teya
# 18.alofi
# 19.clyde river
# 20.murighiol
# 21.ushuaia
# City not found. Skipping...
# 22.yellowknife
# 23.lamar
# 24.bogorodskoye
# 25.kapaa
# 26.lethem
# 27.lagoa
# 28.virginia beach
# 29.buala
# City not found. Skipping...
# 30.batagay-alyta
# 31.havelock
# 32.mataura
# City not found. Skipping...
# 33.east london
# 34.kaabong
# City not found. Skipping...
# City not found. Skipping...
# 35.punta arenas
# 36.lavrentiya
# City not found. Skipping...
# 37.rikitea
# 38.tiksi
# 39.thompson
# 40.saldanha
# 41.maple creek
# 42.orlik
# 43.georgetown
# City not found. Skipping...
# 44.barrow
# 45.tuatapere
# 46.castro
# 47.avarua
# 48.tabou
# 49.faanui
# 50.aswan
# 51.mount isa
# 52.arraial do cabo
# 53.ribeira grande
# 54.mahebourg
# 55.razole
# 56.chuy
# 57.pangnirtung
# 58.sakaiminato
# 59.hobart
# City not found. Skipping...
# 60.hermanus
# 61.oneonta
# 62.basco
# City not found. Skipping...
# 63.tasiilaq
# 64.pisco
# 65.vaini
# City not found. Skipping...
# 66.alindao
# 67.menongue
# 68.san quintin
# City not found. Skipping...
# 69.cape town
# 70.provideniya
# 71.puerto escondido
# 72.comodoro rivadavia
# City not found. Skipping...
# 73.rurrenabaque
# 74.gamba
# 75.tahe
# 76.kodiak
# 77.busselton
# 78.dunedin
# 79.saskylakh
# 80.joshimath
# 81.kavieng
# 82.tempio pausania
# 83.bredasdorp
# 84.ilebo
# 85.constantine
# 86.hilo
# 87.eyrarbakki
# 88.mayo
# 89.evensk
# 90.zabaykalsk
# 91.port-gentil
# 92.mar del plata
# 93.isangel
# City not found. Skipping...
# 94.leh
# 95.baruun-urt
# 96.tres picos
# 97.burnie
# 98.mehamn
# 99.usinsk
# 100.klaksvik
# 101.kupang
# 102.tocopilla
# 103.ahipara
# City not found. Skipping...
# 104.hokitika
# City not found. Skipping...
# 105.poddorye
# 106.carnarvon
# City not found. Skipping...
# 107.mount gambier
# City not found. Skipping...
# City not found. Skipping...
# 108.saint george
# 109.lorengau
# 110.vardo
# 111.birnin kebbi
# 112.nikolskoye
# 113.necochea
# City not found. Skipping...
# 114.upernavik
# 115.vila velha
# 116.ponta do sol
# 117.broken hill
# 118.komsomolskiy
# City not found. Skipping...
# 119.nurota
# 120.camacha
# City not found. Skipping...
# City not found. Skipping...
# 121.severo-kurilsk
# 122.jalu
# 123.sioux lookout
# 124.slidell
# City not found. Skipping...
# 125.dhadar
# City not found. Skipping...
# 126.jamestown
# 127.cherskiy
# 128.ozinki
# 129.yenagoa
# 130.laguna de duero
# 131.qaanaaq
# City not found. Skipping...
# 132.yerbogachen
# City not found. Skipping...
# 133.saint-philippe
# 134.oda
# 135.bougouni
# 136.leningradskiy
# 137.la ronge
# 138.nagutskoye
# 139.makakilo city
# City not found. Skipping...
# 140.santa isabel
# 141.paamiut
# 142.le mans
# 143.marinhas
# 144.khatanga
# City not found. Skipping...
# 145.kahramanmaras
# 146.saint-pierre
# 147.kaitangata
# 148.hithadhoo
# 149.kamaishi
# 150.dingle
# City not found. Skipping...
# 151.havoysund
# City not found. Skipping...
# 152.port hardy
# 153.abu zabad
# City not found. Skipping...
# 154.acapulco
# 155.zhezkazgan
# 156.eskisehir
# 157.tautira
# 158.marawi
# City not found. Skipping...
# 159.geraldton
# 160.norman wells
# 161.nuuk
# 162.raahe
# 163.cockburn town
# 164.bathsheba
# 165.taoudenni
# City not found. Skipping...
# 166.nanortalik
# 167.talovaya
# 168.bhawana
# City not found. Skipping...
# 169.goulburn
# 170.kisangani
# 171.karlivka
# 172.morgan city
# 173.vestmanna
# 174.lompoc
# 175.bilibino
# 176.takoradi
# 177.honningsvag
# 178.quelimane
# 179.sijunjung
# 180.alotenango
# 181.maromitsa
# City not found. Skipping...
# 182.los palacios
# 183.ngunguru
# City not found. Skipping...
# City not found. Skipping...
# 184.guerrero negro
# 185.batemans bay
# 186.adre
# City not found. Skipping...
# 187.male
# 188.raudeberg
# 189.laibin
# 190.tuktoyaktuk
# 191.pochutla
# City not found. Skipping...
# 192.barra do bugres
# 193.zacualtipan
# 194.bambous virieux
# City not found. Skipping...
# 195.kemin
# 196.port elizabeth
# 197.lamu
# 198.ibra
# 199.saint-augustin
# 200.luderitz
# City not found. Skipping...
# 201.coquimbo
# 202.kahului
# City not found. Skipping...
# 203.ajdabiya
# City not found. Skipping...
# City not found. Skipping...
# 204.portland
# 205.cervo
# 206.nadiad
# 207.fomboni
# 208.fortuna
# 209.bontang
# 210.hasaki
# 211.tymovskoye
# 212.kyabram
# City not found. Skipping...
# 213.puerto baquerizo moreno
# 214.mnogovershinnyy
# 215.santiago del estero
# 216.kieta
# 217.amboasary
# 218.verkhoyansk
# 219.victoria
# 220.cascais
# 221.port lincoln
# 222.souillac
# 223.kasempa
# City not found. Skipping...
# 224.conakry
# 225.monte carmelo
# City not found. Skipping...
# 226.tomatlan
# 227.oroquieta
# 228.chapais
# 229.wattegama
# 230.port-cartier
# City not found. Skipping...
# 231.bubaque
# City not found. Skipping...
# City not found. Skipping...
# 232.san andres
# 233.pevek
# City not found. Skipping...
# 234.shihezi
# 235.port augusta
# 236.yangzhou
# 237.fort nelson
# 238.sao filipe
# City not found. Skipping...
# 239.tamiahua
# 240.chatra
# 241.albignasego
# 242.dali
# 243.el fuerte
# City not found. Skipping...
# 244.sur
# 245.pitimbu
# 246.puerto ayora
# 247.morant bay
# 248.ouahigouya
# 249.marsh harbour
# 250.benghazi
# 251.sande
# 252.sarangani
# City not found. Skipping...
# 253.chippewa falls
# 254.longido
# 255.nueva germania
# 256.road town
# City not found. Skipping...
# City not found. Skipping...
# 257.carutapera
# 258.mumford
# 259.balgazyn
# 260.sandwich
# 261.tura
# 262.kota kinabalu
# 263.dangriga
# City not found. Skipping...
# 264.sinnamary
# 265.inhambane
# 266.utica
# 267.chuzhou
# 268.kilindoni
# 269.megali panayia
# 270.sohag
# 271.belle fourche
# 272.sabaudia
# City not found. Skipping...
# 273.topeka
# 274.katsuura
# City not found. Skipping...
# 275.jizan
# 276.aklavik
# City not found. Skipping...
# 277.namibe
# 278.babugarh
# City not found. Skipping...
# 279.aloleng
# 280.marzuq
# 281.coihaique
# 282.erenhot
# 283.cusco
# 284.zyryanovsk
# City not found. Skipping...
# 285.petropavlovsk-kamchatskiy
# 286.longyearbyen
# City not found. Skipping...
# 287.san matias
# City not found. Skipping...
# 288.colares
# 289.madaoua
# City not found. Skipping...
# 290.quchan
# 291.sisimiut
# 292.naklo nad notecia
# 293.hambantota
# 294.beecher
# 295.muros
# 296.flinders
# 297.contamana
# 298.codrington
# 299.margate
# 300.yar-sale
# 301.nishihara
# 302.pyu
# City not found. Skipping...
# 303.ixtapa
# 304.north vernon
# 305.wajima
# City not found. Skipping...
# 306.atar
# 307.mabaruma
# City not found. Skipping...
# 308.collie
# 309.malangas
# 310.faya
# City not found. Skipping...
# 311.jumla
# 312.iqaluit
# 313.ostrovnoy
# 314.seymchan
# City not found. Skipping...
# 315.tomino
# 316.moulins
# 317.gotsu
# City not found. Skipping...
# City not found. Skipping...
# 318.sidi ali
# City not found. Skipping...
# 319.zhoukou
# 320.talnakh
# 321.pierre
# 322.bestobe
# 323.mayor pablo lagerenza
# 324.port blair
# 325.cidreira
# 326.sunel
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 327.formosa do rio preto
# City not found. Skipping...
# 328.ancud
# 329.adrar
# 330.ouegoa
# City not found. Skipping...
# 331.magadan
# 332.mackay
# 333.manggar
# 334.porlamar
# City not found. Skipping...
# 335.cam ranh
# 336.jayanca
# 337.juneau
# 338.veraval
# City not found. Skipping...
# 339.airai
# 340.fairbanks
# 341.chaozhou
# 342.narsaq
# 343.beloha
# 344.sorong
# 345.homer
# 346.roald
# 347.launceston
# 348.buraydah
# 349.lebu
# 350.ribeira brava
# City not found. Skipping...
# 351.otradnoye
# 352.tecpan
# 353.miraflores
# 354.sorland
# City not found. Skipping...
# 355.college
# 356.bandarbeyla
# 357.san cristobal
# 358.mosina
# 359.saint anthony
# 360.masyaf
# 361.waingapu
# City not found. Skipping...
# City not found. Skipping...
# 362.ishigaki
# 363.westport
# 364.selkirk
# 365.hobyo
# City not found. Skipping...
# 366.hamilton
# 367.skoghall
# 368.maua
# City not found. Skipping...
# 369.hohhot
# 370.karrapur
# City not found. Skipping...
# 371.karlskoga
# 372.tahlequah
# 373.ilulissat
# 374.san patricio
# 375.benguela
# City not found. Skipping...
# 376.dubbo
# 377.las margaritas
# 378.rocha
# 379.chokurdakh
# City not found. Skipping...
# 380.livingston
# 381.saint-georges
# 382.srednekolymsk
# 383.velikiy ustyug
# 384.kavaratti
# 385.biak
# City not found. Skipping...
# 386.berdigestyakh
# 387.rio tercero
# 388.half moon bay
# 389.cayenne
# 390.los llanos de aridane
# 391.vila franca do campo
# 392.richards bay
# 393.drezdenko
# City not found. Skipping...
# 394.torbay
# 395.toora-khem
# 396.karratha
# 397.sao gabriel da cachoeira
# City not found. Skipping...
# 398.dubreka
# 399.ruzhyn
# 400.bayir
# 401.fort pierce
# 402.ceuta
# 403.montrose
# 404.belmonte
# 405.yurino
# City not found. Skipping...
# 406.taree
# City not found. Skipping...
# 407.padang
# 408.praia
# City not found. Skipping...
# City not found. Skipping...
# 409.nome
# 410.haines junction
# 411.salinopolis
# 412.weligama
# 413.ayagoz
# 414.lindi
# City not found. Skipping...
# City not found. Skipping...
# 415.kruisfontein
# City not found. Skipping...
# 416.baykit
# 417.montepuez
# City not found. Skipping...
# 418.betsiamites
# City not found. Skipping...
# City not found. Skipping...
# 419.tigil
# 420.corner brook
# 421.kiunga
# 422.cabra
# 423.namatanai
# 424.nouadhibou
# 425.ardakan
# 426.tiarei
# 427.santiago
# 428.vigia del fuerte
# 429.husavik
# City not found. Skipping...
# 430.kaifeng
# City not found. Skipping...
# 431.hirara
# 432.palmdale
# 433.carauari
# City not found. Skipping...
# 434.samarai
# 435.the valley
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 436.calamar
# 437.san miguelito
# 438.esperance
# 439.shushtar
# 440.diffa
# City not found. Skipping...
# City not found. Skipping...
# 441.mandalgovi
# 442.flic en flac
# 443.kulhudhuffushi
# 444.cap-aux-meules
# 445.harper
# City not found. Skipping...
# 446.coaldale
# City not found. Skipping...
# 447.plyussa
# 448.gladstone
# 449.marsa matruh
# 450.abha
# 451.riyadh
# 452.goya
# 453.mujiayingzi
# 454.vinh long
# 455.warmbad
# 456.vao
# City not found. Skipping...
# City not found. Skipping...
# 457.letlhakane
# 458.batticaloa
# City not found. Skipping...
# 459.nantucket
# 460.abrau-dyurso
# 461.davila
# 462.reforma
# City not found. Skipping...
# 463.kailua
# 464.abu kamal
# 465.mahasamund
# City not found. Skipping...
# City not found. Skipping...
# 466.alta floresta
# 467.nova venecia
# 468.zhigansk
# 469.cadolzburg
# City not found. Skipping...
# 470.straumen
# 471.kaeo
# City not found. Skipping...
# 472.reinosa
# 473.erbaa
# 474.turbat
# City not found. Skipping...
# 475.manaure
# 476.flin flon
# 477.bushehr
# 478.sechura
# City not found. Skipping...
# 479.prince rupert
# 480.manokwari
# 481.guane
# 482.tawau
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# 483.galle
# City not found. Skipping...
# 484.rioja
# 485.lahij
# 486.brae
# 487.pedasi
# 488.shahrud
# 489.mugumu
# 490.nosy varika
# 491.crisan
# City not found. Skipping...
# 492.nikki
# 493.swan hill
# 494.jian
# 495.atagay
# 496.port keats
# 497.kumbhraj
# City not found. Skipping...
# 498.demba
# 499.manono
# 500.remedios

# %%
# Verify there are 500 lats and cities in the lists
len(cities)
#len(lats)
dup_count
# Out:
# 130

# %%
df = pd.DataFrame({
        'City Name': cities,
        'Latitude': lats,  
        'Temp': temp_f,
        'Humidity': humidity,
        'Cloudiness': cloudiness,
        'Wind Speed': wind_speed,
    })

df=df.sort_values(['Latitude'], ascending=[True])
ordered_cities=df['City Name'].tolist()
ordered_lats=df['Latitude'].tolist()
df.head()
df.to_csv('weather_data.csv')

# %%
## Verify values

url = "http://api.openweathermap.org/data/2.5/weather?"
units= "imperial"
query_url = f"{url}appid={api_key}&units={units}&q="

response = requests.get(query_url +'collie').json()

#(response['coord']['lat'])
#(response['main']['temp'])
#(response['clouds']['all'])
#(response['main']['humidity'])
#(response['wind']['speed'])

# %%
# Started with seperate loops for cities, weeded out duplicates
# First had a for loop with counter. Debugged by using while loop for counter <30
# This is rather than using a for loop for counter in range (0,30), which was 30 iterations of counter not the value of the counter

# In a SEPERATE loop, used try/except to see if the city had data associated with it for lat
# Had to append None value to list to keep cities and lats the same length

# A more elegant solution was to only append a city to the cities list if it had data associated with it for lat IN THE SAME LOOP
# this eliminated the need to double check. The If statement filtered for duplicates, and the try statement filtered for cities without data.
# If it errored out on the line that set the value for lat, the city was not added to the list.

# And just moved to the next randomized city. Without this step, cities/lats were paired incorrectly, 
# or the lists of cities/lats were different lenghts, which caused an error when we tried to make a dataframe
# I then ordered the lats, then appended the other metrics in a SEPERATE loop
# Once it was working, just added all the metrics to the same try/except statement as for I did for lat and eliminated the seperate loop

# In summary: start off by breaking it into pieces, then put it together to make it more efficient
# I first had 3 seperate loops to break down the problem and find out what wasn't working.
# This is great for debugging, but not efficient for a final product

# %%
plt.grid()
plt.title("Temp(F) vs. Latitude (10/4)")
plt.xlabel('Latitude')
plt.ylabel('Max Temp (F)')
plt.ylim((-10), (120))

plt.scatter(lats, temp_f, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Temp(F) vs. Latitude.png")

# %%
plt.grid()
plt.title("Cloudiness vs. Latitude (10/4)")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness(%)')
plt.ylim((-5), (105))

plt.scatter(lats, cloudiness, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Cloudiness vs. Latitude.png")

# %%
plt.grid()
plt.title("Humidity vs. Latitude (10/4)")
plt.xlabel('Latitude')
plt.ylabel('Humidity(%)')
plt.ylim((0), (105))

plt.scatter(lats, humidity, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Humidity vs. Latitude.png")

# %%
plt.grid()
plt.title("Wind Speed vs. Latitude (10/4)")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed(mph)')
plt.ylim((0), (45))

plt.scatter(lats, wind_speed, marker="o", facecolors="red", edgecolors="black")
plt.savefig("Wind Speed vs. Latitude.png")
